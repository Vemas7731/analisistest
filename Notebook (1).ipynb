# %% [markdown]
# # Proyek Analisis Data: [Analisis Kualitas Udara]
# - **Nama:** [Vemas Adi Pratama]
# - **Email:** [m254b4ky4405@bangkit.academy]
# - **ID Dicoding:** [vemasap]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Kapan Biasanya Terjadi Lonjakan Polusi Udara (Konsentrasi PM 2.5)?
# - Apakah Kecepatan Angin dan Curah Hujan Berpengaruh Pada Konsentrasi PM 2.5 di Udara?
# - Apakah Gas Seperti SO2, NO2, CO, dan O3 Selalu Muncul Saat Konsentrasi PM 2.5 Meningkat?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
#dataset
df_Aotizhongxin = pd.read_csv('PRSA_Data_Aotizhongxin_20130301-20170228.csv')
df_Changping = pd.read_csv('PRSA_Data_Changping_20130301-20170228.csv')
df_Dingling = pd.read_csv('PRSA_Data_Dingling_20130301-20170228.csv')
df_Dongsi = pd.read_csv('PRSA_Data_Dongsi_20130301-20170228.csv')
df_Guanyuan = pd.read_csv('PRSA_Data_Guanyuan_20130301-20170228.csv')
df_Gucheng = pd.read_csv('PRSA_Data_Gucheng_20130301-20170228.csv')
df_Huairou = pd.read_csv('PRSA_Data_Huairou_20130301-20170228.csv')
df_Nongzhanguan = pd.read_csv('PRSA_Data_Nongzhanguan_20130301-20170228.csv')
df_Shunyi = pd.read_csv('PRSA_Data_Shunyi_20130301-20170228.csv')
df_Tiantan = pd.read_csv('PRSA_Data_Tiantan_20130301-20170228.csv')
df_Wanliu = pd.read_csv('PRSA_Data_Wanliu_20130301-20170228.csv')
df_Wanshouxigong = pd.read_csv('PRSA_Data_Wanshouxigong_20130301-20170228.csv')

# %%
#ambil fitur yang dibutuhkan
df_Wanliu = df_Wanliu[['year', 'month', 'day', 'PM2.5', 'station', 'WSPM', 'RAIN','SO2','NO2','CO','O3']]
df_Aotizhongxin = df_Aotizhongxin[['year', 'month', 'day', 'PM2.5', 'station', 'WSPM', 'RAIN','SO2','NO2','CO','O3']]
df_Changping = df_Changping[['year', 'month', 'day', 'PM2.5', 'station', 'WSPM', 'RAIN','SO2','NO2','CO','O3']]
df_Dingling = df_Dingling[['year', 'month', 'day', 'PM2.5', 'station', 'WSPM', 'RAIN','SO2','NO2','CO','O3']]
df_Dongsi = df_Dongsi[['year', 'month', 'day', 'PM2.5', 'station', 'WSPM', 'RAIN','SO2','NO2','CO','O3']]
df_Guanyuan = df_Guanyuan[['year', 'month', 'day', 'PM2.5', 'station', 'WSPM', 'RAIN','SO2','NO2','CO','O3']]
df_Gucheng = df_Gucheng[['year', 'month', 'day', 'PM2.5', 'station', 'WSPM', 'RAIN','SO2','NO2','CO','O3']]
df_Huairou = df_Huairou[['year', 'month', 'day', 'PM2.5', 'station', 'WSPM', 'RAIN','SO2','NO2','CO','O3']]
df_Nongzhanguan = df_Nongzhanguan[['year', 'month', 'day', 'PM2.5', 'station', 'WSPM', 'RAIN','SO2','NO2','CO','O3']]
df_Shunyi = df_Shunyi[['year', 'month', 'day', 'PM2.5', 'station', 'WSPM', 'RAIN','SO2','NO2','CO','O3']]
df_Tiantan = df_Tiantan[['year', 'month', 'day', 'PM2.5', 'station', 'WSPM', 'RAIN','SO2','NO2','CO','O3']]
df_Wanshouxigong = df_Wanshouxigong[['year', 'month', 'day', 'PM2.5', 'station', 'WSPM', 'RAIN','SO2','NO2','CO','O3']]

# %%
#gabungin dataset
df_allstation = pd.concat([df_Wanliu, df_Aotizhongxin, df_Changping,
                            df_Dingling, df_Dongsi, df_Guanyuan,
                            df_Gucheng, df_Huairou, df_Nongzhanguan,
                            df_Shunyi, df_Tiantan, df_Wanshouxigong])
print('DataFrame Awal : ', df_allstation)
# Out:
# DataFrame Awal :         year  month  day  PM2.5        station  WSPM  RAIN  SO2   NO2     CO  \
# 0      2013      3    1    8.0         Wanliu   4.4   0.0  6.0  28.0  400.0
# 1      2013      3    1    9.0         Wanliu   4.7   0.0  6.0  28.0  400.0
# 2      2013      3    1    3.0         Wanliu   5.6   0.0  NaN  19.0  400.0
# 3      2013      3    1   11.0         Wanliu   3.1   0.0  8.0  14.0    NaN
# 4      2013      3    1    3.0         Wanliu   2.0   0.0  9.0   NaN  300.0
# ...     ...    ...  ...    ...            ...   ...   ...  ...   ...    ...
# 35059  2017      2   28   11.0  Wanshouxigong   2.4   0.0  3.0  24.0  400.0
# 35060  2017      2   28   13.0  Wanshouxigong   0.9   0.0  3.0  41.0  500.0
# 35061  2017      2   28   14.0  Wanshouxigong   1.1   0.0  4.0  38.0  500.0
# 35062  2017      2   28   12.0  Wanshouxigong   1.2   0.0  4.0  30.0  400.0
# 35063  2017      2   28   13.0  Wanshouxigong   1.3   0.0  4.0  38.0  600.0
#
#          O3
# 0      52.0
# 1      50.0
# 2      55.0
# 3       NaN
# 4      54.0
# ...     ...
# 35059  72.0
# 35060  50.0
# 35061  54.0
# 35062  59.0
# 35063  49.0
#
# [420768 rows x 11 columns]

# %%
#satuin tiga fitur ('year', 'month', 'day') jadi satu fitur aja ('date')
df_allstation['date'] = pd.to_datetime(df_allstation[['year', 'month', 'day']])
df_allstation.drop(columns=['year', 'day'], inplace=True)
print(df_allstation)
# Out:
#        month  PM2.5        station  WSPM  RAIN  SO2   NO2     CO    O3  \
# 0          3    8.0         Wanliu   4.4   0.0  6.0  28.0  400.0  52.0
# 1          3    9.0         Wanliu   4.7   0.0  6.0  28.0  400.0  50.0
# 2          3    3.0         Wanliu   5.6   0.0  NaN  19.0  400.0  55.0
# 3          3   11.0         Wanliu   3.1   0.0  8.0  14.0    NaN   NaN
# 4          3    3.0         Wanliu   2.0   0.0  9.0   NaN  300.0  54.0
# ...      ...    ...            ...   ...   ...  ...   ...    ...   ...
# 35059      2   11.0  Wanshouxigong   2.4   0.0  3.0  24.0  400.0  72.0
# 35060      2   13.0  Wanshouxigong   0.9   0.0  3.0  41.0  500.0  50.0
# 35061      2   14.0  Wanshouxigong   1.1   0.0  4.0  38.0  500.0  54.0
# 35062      2   12.0  Wanshouxigong   1.2   0.0  4.0  30.0  400.0  59.0
# 35063      2   13.0  Wanshouxigong   1.3   0.0  4.0  38.0  600.0  49.0
#
#             date
# 0     2013-03-01
# 1     2013-03-01
# 2     2013-03-01
# 3     2013-03-01
# 4     2013-03-01
# ...          ...
# 35059 2017-02-28
# 35060 2017-02-28
# 35061 2017-02-28
# 35062 2017-02-28
# 35063 2017-02-28
#
# [420768 rows x 10 columns]

# %% [markdown]
# **Insight:**
# - Dataset yang digunakan adalah gabungan dari seluruh dataset yang ada pada folder, namun saya menyortir hanya beberapa fitur yang dibutuhkan.
# - Setelah dataset digabung dan disortir, langkah selanjutnya adalah menyatukan tiga fitur (year, month, day) menjadi satu fitur bernama date. Bertujuan agar memudahkan analisis.
#
# Berikut fitur-fitur yang digunakan
#
# - month : bulan (Melihat konsentrasi 2.5, dan gas gas berbahaya dalam periode bulanan)
# - PM2.5 : konsentrasi partikel polusi mikro
# - station : tempat stasiun di Beijing
# - WSPM : kecepatan angin
# - RAIN : curah hujan
# - SO2 : konsentrasi gas SO2 di udara
# - NO2 : konsentrasi gas NO2 di udara
# - CO : konsentrasi gas CO di udara
# - O3 : konsentrasi gas O3 di udara
#
# - Jumlah data (uncleaned) : 420.768 data

# %% [markdown]
# ### Assessing Data

# %%
#cek missing values
cek_missing = df_allstation.isnull().sum()
print(cek_missing)
# Out:
# month          0
# PM2.5       8739
# station        0
# WSPM         318
# RAIN         390
# SO2         9021
# NO2        12116
# CO         20701
# O3         13277
# date           0
# dtype: int64

# %%
#cek duplikat
cek_duplikat = df_allstation.duplicated().sum()
print('Duplikat : ', cek_duplikat)
# Out:
# Duplikat :  893

# %%
# Cek Outlier
Q1 = df_allstation['PM2.5'].quantile(0.25)
Q3 = df_allstation['PM2.5'].quantile(0.75)
IQR = Q3 - Q1

# Tentukan batas untuk outlier
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter outlier
outliers = df_allstation[(df_allstation['PM2.5'] < lower_bound) | (df_allstation['PM2.5'] > upper_bound)]
print('Jumlah outlier pada PM2.5: ', outliers.shape[0])
print(outliers[['PM2.5', 'date']])
# Out:
# Jumlah outlier pada PM2.5:  19142
#        PM2.5       date
# 118    270.0 2013-03-05
# 119    268.0 2013-03-05
# 136    249.0 2013-03-06
# 137    259.0 2013-03-06
# 138    248.0 2013-03-06
# ...      ...        ...
# 34755  266.0 2017-02-16
# 34756  264.0 2017-02-16
# 34757  262.0 2017-02-16
# 34758  261.0 2017-02-16
# 34759  256.0 2017-02-16
#
# [19142 rows x 2 columns]

# %% [markdown]
# **Insight:**
# - Setelah kita mendapatkan data, langkah selanjutnya adalah mengecek data, apakah ada missing value, duplikat, dan outlier pada data tersebut?
# - Ternyata masih terdapat ketiga aspek tersebut :
#
# - Missing value : 64562 sampel
# - Duplikat : 893
# - Outlier (Fitur PM2.5) : 19142 sampel (Fitur lainnya juga akan dibersihkan pada tahap selanjutnya)

# %% [markdown]
# ### Cleaning Data

# %%
#interpolation missing values karena dataset bertipe time series
df_allstation['PM2.5'].interpolate(method='linear', limit_direction='forward', inplace=True)
df_allstation['WSPM'].interpolate(method='linear', limit_direction='forward', inplace=True)
df_allstation['RAIN'].interpolate(method='linear', limit_direction='forward', inplace=True)
df_allstation['SO2'].interpolate(method='linear', limit_direction='forward', inplace=True)
df_allstation['NO2'].interpolate(method='linear', limit_direction='forward', inplace=True)
df_allstation['CO'].interpolate(method='linear', limit_direction='forward', inplace=True)
df_allstation['O3'].interpolate(method='linear', limit_direction='forward', inplace=True)

#cek missing values
cek_missing = df_allstation.isnull().sum()
print(cek_missing)
# Out:
# month      0
# PM2.5      0
# station    0
# WSPM       0
# RAIN       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# date       0
# dtype: int64
# <ipython-input-50-697c8c539521>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_allstation['PM2.5'].interpolate(method='linear', limit_direction='forward', inplace=True)
# <ipython-input-50-697c8c539521>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_allstation['WSPM'].interpolate(method='linear', limit_direction='forward', inplace=True)
# <ipython-input-50-697c8c539521>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_allstation['RAIN'].interpolate(method='linear', limit_direction='forward', inplace=True)
# <ipython-input-50-697c8c539521>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_allstation['SO2'].interpolate(method='linear', limit_direction='forward', inplace=True)
# <ipython-input-50-697c8c539521>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_allstation['NO2'].interpolate(method='linear', limit_direction='forward', inplace=True)
# <ipython-input-50-697c8c539521>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_allstation['CO'].interpolate(method='linear', limit_direction='forward', inplace=True)
# <ipython-input-50-697c8c539521>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_allstation['O3'].interpolate(method='linear', limit_direction='forward', inplace=True)

# %%
#hapus duplikat
df_allstation.drop_duplicates(inplace=True)
cek_duplikat = df_allstation.duplicated().sum()
print(df_allstation)

print('Duplikat : ', cek_duplikat)
# Out:
#        month  PM2.5        station  WSPM  RAIN  SO2   NO2     CO    O3  \
# 0          3    8.0         Wanliu   4.4   0.0  6.0  28.0  400.0  52.0
# 1          3    9.0         Wanliu   4.7   0.0  6.0  28.0  400.0  50.0
# 2          3    3.0         Wanliu   5.6   0.0  7.0  19.0  400.0  55.0
# 3          3   11.0         Wanliu   3.1   0.0  8.0  14.0  350.0  54.5
# 4          3    3.0         Wanliu   2.0   0.0  9.0  15.5  300.0  54.0
# ...      ...    ...            ...   ...   ...  ...   ...    ...   ...
# 35059      2   11.0  Wanshouxigong   2.4   0.0  3.0  24.0  400.0  72.0
# 35060      2   13.0  Wanshouxigong   0.9   0.0  3.0  41.0  500.0  50.0
# 35061      2   14.0  Wanshouxigong   1.1   0.0  4.0  38.0  500.0  54.0
# 35062      2   12.0  Wanshouxigong   1.2   0.0  4.0  30.0  400.0  59.0
# 35063      2   13.0  Wanshouxigong   1.3   0.0  4.0  38.0  600.0  49.0
#
#             date
# 0     2013-03-01
# 1     2013-03-01
# 2     2013-03-01
# 3     2013-03-01
# 4     2013-03-01
# ...          ...
# 35059 2017-02-28
# 35060 2017-02-28
# 35061 2017-02-28
# 35062 2017-02-28
# 35063 2017-02-28
#
# [420652 rows x 10 columns]
# Duplikat :  0

# %%
#hilangin outlier PM 2.5
sebelumoutlier = df_allstation.shape[0]
q1 = (df_allstation['PM2.5'].quantile(0.25))
q3 = (df_allstation['PM2.5'].quantile(0.75))
iqr = q3-q1

maximum = q3 + (1.5*iqr)
minimum = q1 - (1.5*iqr)

kondisi_lower_than = df_allstation['PM2.5'] < minimum
kondisi_more_than = df_allstation['PM2.5'] > maximum

df_allstation.drop(df_allstation[kondisi_lower_than | kondisi_more_than].index, inplace=True)
setelahoutlier = df_allstation.shape[0]
outliertereliminasi = sebelumoutlier - setelahoutlier

print('Jumlah Outlier Fitur PM 2.5 yang Dibuang : ', outliertereliminasi)
# Out:
# Jumlah Outlier Fitur PM 2.5 yang Dibuang :  41619

# %%
#hilangin outlier WSPM
sebelumoutlier = df_allstation.shape[0]
q1 = (df_allstation['WSPM'].quantile(0.25))
q3 = (df_allstation['WSPM'].quantile(0.75))
iqr = q3-q1

maximum = q3 + (1.5*iqr)
minimum = q1 - (1.5*iqr)

kondisi_lower_than = df_allstation['WSPM'] < minimum
kondisi_more_than = df_allstation['WSPM'] > maximum

df_allstation.drop(df_allstation[kondisi_lower_than | kondisi_more_than].index, inplace=True)
setelahoutlier = df_allstation.shape[0]
outliertereliminasi = sebelumoutlier - setelahoutlier

print('Jumlah Outlier yang Dibuang : ', outliertereliminasi)
# Out:
# Jumlah Outlier yang Dibuang :  53989

# %%
#Outlier RAIN
sebelumoutlier = df_allstation.shape[0]
q1 = df_allstation['WSPM'].quantile(0.25)
q3 = df_allstation['WSPM'].quantile(0.75)
iqr = q3 - q1

maximum = q3 + (1.5 * iqr)
minimum = q1 - (1.5 * iqr)

kondisi_lower_than = df_allstation['WSPM'] < minimum
kondisi_more_than = df_allstation['WSPM'] > maximum

df_allstation.drop(df_allstation[kondisi_lower_than | kondisi_more_than].index, inplace=True)
setelahoutlier = df_allstation.shape[0]
outliertereliminasi = sebelumoutlier - setelahoutlier

print('Jumlah Outlier yang Dibuang :', outliertereliminasi)
# Out:
# Jumlah Outlier yang Dibuang : 45410

# %% [markdown]
# **Insight:**
# - Untuk mendapatkan hasil analisis yang maksimal dataset tersebut harus dibersihkan terlebih dahulu dari missing values, duplicates, dan outlier.
# - pembersihan missing values dilakukan dengan metode interpolation dikarenakan dataset tersebut bertipe time series. Metode tersebut juga dilakukan untuk menghindari penghapusan informasi yang berharga.
# - missing values kini berjumlah 0
# - duplicates kini berjumlah 0
# - dari penghapusan outlier, kita telah menghapus 140.018 data. atau sekitar 33% data

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Korelasi

# %%
print(df_allstation['PM2.5'].describe())
# Out:
# count    279634.000000
# mean         70.294323
# std          51.975828
# min           2.000000
# 25%          27.000000
# 50%          59.000000
# 75%         102.000000
# max         247.250000
# Name: PM2.5, dtype: float64

# %%
#korelasi kecepatan angin dan tingkat PM 2.5
korelasiangin = df_allstation[['WSPM', 'PM2.5']].corr()
print('Korelasi kecepatan angin dengan tingkat polusi : ')
print(korelasiangin)
# Out:
# Korelasi kecepatan angin dengan tingkat polusi :
#            WSPM     PM2.5
# WSPM   1.000000 -0.117382
# PM2.5 -0.117382  1.000000

# %%
#korelasi hujan dan tingkat PM 2.5
korelasiangin = df_allstation[['RAIN', 'PM2.5']].corr()
print('Korelasi hujan dengan tingkat polusi : ')
print(korelasiangin)
# Out:
# Korelasi hujan dengan tingkat polusi :
#            RAIN     PM2.5
# RAIN   1.000000 -0.016508
# PM2.5 -0.016508  1.000000

# %%
#korelasi gas SO2 NO2 CO O3 dengan tingkat pm2.5
#SO2
korelasiso2 = df_allstation[['SO2', 'PM2.5']].corr()
print('Korelasi Munculnya Gas SO2 dengan Waktu Polusi : ')
print(korelasiso2)
# Out:
# Korelasi Munculnya Gas SO2 dengan Waktu Polusi :
#             SO2     PM2.5
# SO2    1.000000  0.411997
# PM2.5  0.411997  1.000000

# %%
#NO2
korelasino2 = df_allstation[['NO2', 'PM2.5']].corr()
print('Korelasi Munculnya Gas NO2 dengan Waktu Polusi : ')
print(korelasino2)
# Out:
# Korelasi Munculnya Gas NO2 dengan Waktu Polusi :
#            NO2    PM2.5
# NO2    1.00000  0.50844
# PM2.5  0.50844  1.00000

# %%
#CO
korelasico = df_allstation[['CO', 'PM2.5']].corr()
print('Korelasi Munculnya Gas CO dengan Waktu Polusi : ')
print(korelasico)
# Out:
# Korelasi Munculnya Gas CO dengan Waktu Polusi :
#             CO    PM2.5
# CO     1.00000  0.65213
# PM2.5  0.65213  1.00000

# %%
#O3
korelasio3 = df_allstation[['O3', 'PM2.5']].corr()
print('Korelasi Munculnya Gas O3 dengan Waktu Polusi : ')
print(korelasio3)
# Out:
# Korelasi Munculnya Gas O3 dengan Waktu Polusi :
#              O3     PM2.5
# O3     1.000000 -0.048178
# PM2.5 -0.048178  1.000000

# %% [markdown]
# **Insight:**
# - Mengingat kita ingin mencari korelasi antara hujan dan PM 2.5, juga angin dengan PM 2.5, juga PM 2.5 dengan seluruh gas berbahaya. maka kita buktikan apakah fitur fitur tersebut saling berkorelasi atau tidak
# - korelasi kecepatan angin dengan konsentrasi PM 2.5 adalah -0.117. Karena negatif berarti korelasinya berlawanan. Namun sangat tidak signifikan karena mendekati 0. sehingga bisa disimpulkan bahwa angin yang berhembus kencang tidak mempengaruhi penurunan kualitas udara.
# - korelasi curah hujan dengan konsentrasi PM 2.5 adalah -0.016. Karena negatif berarti korelasinya berlawanan. Namun sangat tidak signifikan karena mendekati 0. sehingga bisa disimpulkan bahwa curah hujan juga tidak mempengaruhi penurunan kualitas udara.
# -korelasi gas berbahaya dengan konsentrasi PM 2.5 adalah sebagai berikut : SO2(0.411), NO2(0.508), CO(0.652), dan O3(-0.049). konsentrasi gas SO2, NO2, dan CO cukup signifikan ketika polusi udara meningkat. sedangkan gas O3 tidak memiliki korelasi dengan parahnya kualitas udara

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
#kapan biasanya lonjakan polusi udara
df_lonjakanpolusi = df_allstation.groupby('date')[['PM2.5']].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='date', y='PM2.5', data=df_lonjakanpolusi, marker='o', color='blue', label='WSPM')
plt.title('Persebaran Polusi Udara Per Tahun', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Konsentrasi PM2.5', fontsize=12)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#rata rata pm 2.5 per bulan
df_rata2_pm_per_bulan = df_allstation.groupby('month')['PM2.5'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='month', y='PM2.5', data=df_rata2_pm_per_bulan, color='blue')
plt.title('Rata-rata Konsentrasi PM2.5 per Bulan', fontsize=14)
plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Rata-Rata Konsentrasi PM2.5', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 2 & 3:

# %% [markdown]
# ### Pertanyaan 2

# %%
#korelasi angin dan hujan heatmap
correlation_matrix = df_allstation[['WSPM', 'RAIN', 'PM2.5']].corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True, linewidths=0.5, cbar_kws={"shrink": .8})
plt.title('Heatmap Korelasi Kecepatan Angin, Hujan, dan PM2.5', fontsize=14)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
#line chart kecepatan angin tahunan
df_angindanhujantahunan = df_allstation.groupby('date')[['WSPM', 'RAIN']].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(x='date', y='WSPM', data=df_angindanhujantahunan, marker='o', color='blue', label='WSPM')
plt.title('Rata-rata Kecepatan Angin Tahunan', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Kecepatan Angin (WSPM)', fontsize=12)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#line chart curah hujan tahunan
plt.figure(figsize=(10, 6))
sns.lineplot(x='date', y='RAIN', data=df_angindanhujantahunan, marker='o', color='green', label='RAIN')
plt.title('Rata-rata Curah Hujan Tahunan', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Curah Hujan (RAIN)', fontsize=12)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 3

# %%
# Mengambil fitur yang relevan untuk korelasi
df_korelasi_gas = df_allstation[['PM2.5', 'SO2', 'NO2', 'CO', 'O3']]

# Menghitung korelasi
korelasi_gas = df_korelasi_gas.corr()

# Visualisasi heatmap korelasi
plt.figure(figsize=(8, 6))
sns.heatmap(korelasi_gas, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Heatmap Korelasi PM2.5 dengan Gas (SO2, NO2, CO, O3)', fontsize=14)
plt.tight_layout()
plt.show()

# %%
#rata rata gas SO2 NO2 CO O3 per bulan
#SO2
df_so2_per_bulan = df_allstation.groupby('month')['SO2'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='month', y='SO2', data=df_so2_per_bulan, color='blue')
plt.title('Rata-rata Konsentrasi SO2 per Bulan', fontsize=14)
plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Rata-Rata Konsentrasi SO2', fontsize=12)
plt.tight_layout()
plt.show()

# %%
#NO2
df_no2_per_bulan = df_allstation.groupby('month')['NO2'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='month', y='NO2', data=df_no2_per_bulan, color='blue')
plt.title('Rata-rata Konsentrasi NO2 per Bulan', fontsize=14)
plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Rata-Rata Konsentrasi NO2', fontsize=12)
plt.tight_layout()
plt.show()

# %%
#CO
df_co_per_bulan = df_allstation.groupby('month')['CO'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='month', y='CO', data=df_co_per_bulan, color='blue')
plt.title('Rata-rata Konsentrasi CO per Bulan', fontsize=14)
plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Rata-Rata Konsentrasi CO', fontsize=12)
plt.tight_layout()
plt.show()

# %%
#O3
df_o3_per_bulan = df_allstation.groupby('month')['O3'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='month', y='O3', data=df_o3_per_bulan, color='blue')
plt.title('Rata-rata Konsentrasi O3 per Bulan', fontsize=14)
plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Rata-Rata Konsentrasi O3', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - Terdapat pola tertentu pada kualitas udara di stasiun beijing. konsentrasi PM 2.5 yang tinggi selalu muncul di awal dan akhir tahun antara november-maret, dan membaik di kisaran bulan agustus-september
# - index korelasi angin atau hujan terhadap konsentrasi PM 2.5 di udara cenderung mendekati 0, sehingga tidak memiliki korelasi sama sekali
# - kecepatan angin tinggi di awal tahun dan rendah di pertengahan tahun
# - curah hujan tinggi di pertengahan tahun dan rendah di awal tahun
# - konsentrasi gas SO2, NO2, dan CO cukup signifikan saat indeks PM 2.5 tinggi. Kemungkinan besar gas inilah yang muncul ketika udara berpolusi
# - konsentrasi gas O3 tidak memiliki korelasi signifikan dengan tingginya indeks PM 2.5
# - konsentrasi gas SO2, NO2, dan CO cukup signifikan pada awal tahun dan akhir tahun
# - konsentrasi gas O3 cukup signifikan pada pertengahan tahun

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# Saya membuat map folium yang tertera pada dashboard
#
# akses : https://airqualitystation.streamlit.app/

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Kapan Biasanya Terjadi Lonjakan Polusi Udara (Konsentrasi PM 2.5)?
#
# Conclusion :
#
# Puncak polusi udara biasanya terjadi pada awal dan akhir tahun. Untuk pencegahan pola polusi yang berkelanjutan, sebaiknya segera dilakukan tindakan preventif pada bulan bulan sebelum puncak, dan penganalisaan faktor faktor penyebab tingginya polusi udara pada puncak polusi terjadi. sehingga kualitas udara akan selalu bersih sepanjang tahun
# - Apakah Kecepatan Angin dan Curah Hujan Berpengaruh Pada Konsentrasi PM 2.5 di
# Udara?
#
# Conclusion :
#
# Cepatnya angin dan Curah hujan tinggi ternyata tidak terlalu berpengaruh untuk menangani kualitas udara yang buruk. Diperlukan langkah lain seperti pembatasan kendaraan berpolusi tinggi, mengganti energi kotor menjadi energi yang lebih berkelanjutan, atau langkah langkah lainnya.
# - Apakah Gas Seperti SO2, NO2, CO, dan O3 Selalu Muncul Saat Konsentrasi PM 2.5 Meningkat?
#
# Conclusion :
#
# Beberapa gas yang perlu diwaspadai karena kemungkinan besar muncul adalah SO2, SO3, dan CO. Gas tersebut berbahaya apabila dihirup oleh manusia, terlebih bagi yang memiliki sensitif asma atau penyakit pernapasan lainnya. sehingga sangat direkomendasikan untuk mengenakan masker saat tingkat polusi tinggi jika mengharuskan untuk keluar rumah.
